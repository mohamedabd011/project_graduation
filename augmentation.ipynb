# %%
import tensorflow as tf
from tensorflow import keras

# %%
import numpy as np
import cv2

# %% [markdown]
# # prepare DATA

# %%
import cv2
import os
import matplotlib.pyplot as plt


def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        
        img=cv2.resize(img,(800,800))              # Set whatever size you want 
        img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img=tf.reshape(img, [1, 800, 800, 3])
        if img is not None:
            images.append(img)
    return images

# %%
X=load_images_from_folder('D:\\final project\\archive(1)\\OralCancer\\cancer')

# %%
...
# create data generator
datagen = keras.preprocessing.image.ImageDataGenerator()

# %%
it = datagen.flow(X)

# %%
it

# %% [markdown]
# # shift width_

# %%
from matplotlib import pyplot
datagen = keras.preprocessing.image.ImageDataGenerator(width_shift_range=[-200,200])
# prepare iterator
it = datagen.flow(X[0], batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
    
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# # shift height

# %%
datagen_2 = keras.preprocessing.image.ImageDataGenerator(height_shift_range=0.5)
# prepare iterator
it_2 = datagen_2.flow(X[1], batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch_2 = it_2.next()
	# convert to unsigned integers for viewing
	image = batch_2[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# # rotation

# %%
datagen_3 = keras.preprocessing.image.ImageDataGenerator(rotation_range=90)
# prepare iterator
it_3 = datagen_3.flow(X[2], batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it_3.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# # random zoom

# %%
datagen_4 = keras.preprocessing.image.ImageDataGenerator(zoom_range=[0.5,2.0])
# prepare iterator
it_4 = datagen_4.flow(X[2], batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it_4.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# # brightness

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(brightness_range=[0.2,1.0])
# prepare iterator
it = datagen.flow(X[5], batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
import numpy as np
import cv2

from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
import numpy as np
import os
from PIL import Image
#image_directory = r'D:\\final project\\cancer'
SIZE = 224
dataset = []

def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img=cv2.resize(img,(224,224))             # Set whatever size you want 
        if img is not None:
            images.append(img)
    return images
dataset=load_images_from_folder(r'D:\\final project\\cancer')


Data_type = object
x = np.array(dataset)
x=np.array(x, dtype=Data_type)
i = 0
for batch in datagen.flow(x, batch_size=16,
                          save_to_dir= r'D:\\final project\\new',
                          save_prefix='dr',
                          save_format='jpg'):    
    i += 1    
    if i > 50:        
        break

# %%
x
# Out:
# array([array([[[255, 255, 255],
#         [254, 254, 255],
#         [253, 254, 255],
#         ...,
#         [252, 253, 253],
#         [254, 254, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [244, 248, 255],
#         [226, 236, 255],
#         ...,
#         [213, 223, 236],
#         [246, 246, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 255],
#         [232, 240, 255],
#         [202, 213, 255],
#         ...,
#         [170, 186, 220],
#         [234, 240, 249],
#         [255, 255, 255]],
#
#        ...,
#
#        [[254, 254, 255],
#         [237, 241, 255],
#         [214, 227, 255],
#         ...,
#         [ 96,  97, 101],
#         [213, 219, 219],
#         [238, 246, 238]],
#
#        [[255, 255, 255],
#         [251, 253, 255],
#         [247, 248, 255],
#         ...,
#         [213, 219, 219],
#         [228, 238, 235],
#         [246, 250, 246]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
# ...
